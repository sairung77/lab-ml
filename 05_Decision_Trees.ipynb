# %% [markdown]
# # Week11 -  Decision Trees and Random Forests
# # ADV Python for DS
#
# Revised from Jose Portilla's course
# ___

# %% [markdown]
# **Dataset**
#
# 1) Kyphosis (หลังค่อม): Absent or Present (After spinal surgery)
#
# 2) Age: Age of the person in months
#
# 3) Number: The number of vertebrae (กระดูกสันหลัง)
#
# 4) Start: The top most of vertebrae that was operated on
#
# ![Screenshot 2022-11-11 101752.jpg](data:image/jpeg;base64,...)
#
# # 1) Import Libraries

# %%
# Enter your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2) Get the Data

# %%
# Upload  'kyphosis.csv'
# Enter your code here
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f7559f40-ffaf-4a7b-abef-0a855860652d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7559f40-ffaf-4a7b-abef-0a855860652d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Read 'kyphosis.csv' as a dataframe
import io
df = pd.read_csv(io.BytesIO(uploaded['kyphosis (2).csv']))
df
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# ..      ...  ...     ...    ...
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13
#
# [81 rows x 4 columns]

# %%
# Show the first 5 rows

# Enter your code here

# %%
# Show description of the data in the DataFrame

# Enter your code here

# %%
# Show information about the DataFrame

# Enter your code here

# %% [markdown]
# # 3) EDA
#
# We'll just check out a simple pairplot for this small dataset.

# %%
# Display Pairplot with hue='Kyphosis'

# Enter your code here

# Create the pairplot with hue='Kyphosis'


# Add a title for clarity
plt.suptitle('Pairplot of Kyphosis Dataset by Outcome', y=1.02)

# Display the plot
plt.show()

# %% [markdown]
# # 4) Train Test Split
#
# Let's split up the data into a training set and a test set!

# %%
# Import train_test_split
from sklearn.model_selection import train_test_split

# Enter your code here
# Step 1: Define features (X) and target (y)
X = df.drop('Kyphosis', axis=1)
y = df['Kyphosis']

# Step 2: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# Optional: Print the shapes to verify the split
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)

# %%
# Define X and y

# Enter your code here
# Define X (features) by dropping the 'Kyphosis' column
# axis=1 specifies that you are dropping a column


# Define y (target) by selecting the 'Kyphosis' column


# Print the first few rows of X and y to verify
print("Features (X):")
print(X.head())
print("\nTarget (y):")
print(y.head())

# %%
# Split arrays into random train and test subsets (70:30)

# Enter your code here

# Optional: Print the shapes to confirm the split
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)

# %% [markdown]
# # 5) Decision Trees
#
# We'll start just by training a single decision tree.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Create DecisionTreeClassifier as dtree

# Enter your code here

# %%
# Train (fit) dtree (X_train,y_train)

# Enter your code here

# %% [markdown]
# # 6) Prediction and Evaluation
#
# Let's evaluate our decision tree.

# %%
# Predict X_test

predictions = dtree.predict(X_test)

# %%
# Import classification_report, confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# Print confusion_matrix

print("Confusion Matrix:")
print(confusion_matrix(y_test, predictions))

# %%
# Print classification_report

print("\nClassification Report:")
print(classification_report(y_test, predictions))

# %% [markdown]
# # 7) Tree Visualization
#
# Scikit learn actually has some built-in visualization capabilities for decision trees, you won't use this often and it requires you to install the pydot library, but here is an example of what it looks like and the code to execute this:
#
# Remark: *Pydot* is a Python library, also written in Python, that "serves as a graphical interface to Graphviz, an open source graph visualization software.

# %%
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydot
from six import StringIO

features = list(df.columns[1:])
features

# %%
dot_data = StringIO()

export_graphviz(dtree, out_file=dot_data, feature_names=features, class_names=['absent','present'], filled=True, rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph[0].create_png())

# %% [markdown]
# # 8) Random Forests
#
# Now let's compare the decision tree model to a random forest.

# %%
# Import RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier

# %%
# Create RandomForestClassifier as rfc with n_estimators=100

rfc = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# Train (fit) rfc (X_train,y_train)


# Enter your code here

# %%
# Predict X_test


# Enter your code here

# %%
# Print confusion_matrix

# Enter your code here

# %%
# Print classification_report

# Enter your code here

# %% [markdown]
# # Great Job!
