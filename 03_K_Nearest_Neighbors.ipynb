# %% [markdown]
# # Week11 - K Nearest Neighbors
# # Adv Python for DS
#
# Revised from Jose Portilla's course
#
# ---
#
#
# You have been given a classified data set from a company. They have hidden the feature column names but have given you the data and the target classes.
#
# We will try to use KNN to create a model that directly predicts a class for a new data point based off of the features.

# %% [markdown]
# # 1) Check out the data

# %% [markdown]
# 1.1 Import Libraries

# %%
# Enter your code here

# %% [markdown]
# 1.2 Get the Data
#
# Set index_col=0 to use the first column as the index.

# %%
# Import dataset ("Classified Data")

# Enter your code here

# %%
# Your code goes here

# %%
# Display the first 5 rows

# Enter your code here

# %%
# Display 'information' about the DataFrame

# Enter your code here

# %%
# Display 'description' of the data in the DataFrame

# Enter your code here

# %% [markdown]
# # 2) Standardize the Variables
#
# Because the KNN classifier predicts the class of a given test observation by identifying the observations that are nearest to it, the scale of the variables matters.
# Any variables that are on a large scale will have a much larger effect on the distance between the observations, and hence on the KNN classifier, than variables that are on a small scale.

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Standardize features by removing the mean and scaling to unit variance.
#
# The standard score of a sample x is calculated as:
#
# z = (x - u) / s
#
# ข้อมูลที่ทำเป็นมาตรฐานแล้ว = (ข้อมูลเดิม - ค่าเฉลี่ย)/ส่วนเบี่ยงเบนมาตรฐาน
#
# where u is the mean of the training samples ,
# and s is the standard deviation of the training samples.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %%
scaler = StandardScaler()

# %% [markdown]
# Every scikit-learn's transform's **fit()** just calculates the parameters
# (e.g. μ and σ in case of StandardScaler) and saves them as an internal object's state.
#
# Just a computation, nothing is given to you!

# %%
scaler.fit(df.drop('TARGET CLASS',axis=1)) # drop 'TARGET CLASS' column

# %%
# print mean and std
print(scaler.mean_) #mean
print(scaler.scale_) #std

# %% [markdown]
# **transform** uses a *previously* computed mean and std to autoscale the data (subtract mean from all values and then divide it by std).

# %%
scaled_features = scaler.transform(df.drop('TARGET CLASS',axis=1))

# %% [markdown]
# **Remark:**
#
# **fit_transform** does both at the same time.
# So you can do it with 1 line of code instead of 2.
#
# *Example,* scaled_features = scaler.fit_transform(df.drop('TARGET CLASS',axis=1)
#
# ----------------------
# Now let's look at it in practice when training and test sets are separated:
#
# - For *X training set*, we do **fit_transform** because we need to compute mean and std, and then use it to autoscale the data.
#
# - For *X test set*, well, we *already have* the mean and std, so we only do the transform part.

# %%
df_feature = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feature.head()
# Out:
#    Unnamed: 0       WTT       PTI       EQW       SBI       LQE       QWG  \
# 0   -1.730320 -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375
# 1   -1.726856 -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706
# 2   -1.723391 -0.788702  0.339318  0.301511  0.755873  2.031693 -0.870156
# 3   -1.719927  0.982841  1.060193 -0.621399  0.625299  0.452820 -0.267220
# 4   -1.716463  1.139275 -0.640392 -0.709819 -0.057175  0.822886 -0.936773
#
#         FDJ       PJF       HQE       NXJ
# 0 -0.798951 -1.482368 -0.949719 -0.643314
# 1 -1.129797 -0.202240 -1.828051  0.636759
# 2  2.599818  0.285707 -0.682494 -0.377850
# 3  1.750208  1.066491  1.241325 -1.026987
# 4  0.596782 -1.472352  1.040772  0.276510

# %% [markdown]
# # 3) Train Test Split

# %%
# import "train_test_split" from sklearn

# Enter your code here

# %%
# Split dataset into training and test sets (trainn 70%, test 30%)

# Define X (features) - all columns except the target
# Assuming 'TARGET CLASS' is the target variable in 'Classified Data.csv'
X = df.drop('TARGET CLASS', axis=1)

# Define y (target)
y = df['TARGET CLASS']

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# Verify the shapes of the resulting sets
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (700, 11)
# Shape of y_train: (700,)
# Shape of X_test: (300, 11)
# Shape of y_test: (300,)

# %% [markdown]
# # 4) Create KNN model
#
# Remember that we are trying to come up with a model to predict whether someone will TARGET CLASS or not. We'll start with k=1.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Create kNN classifier (model)
knn = KNeighborsClassifier(n_neighbors=1, weights='uniform')

# 'n_neighbors': int, Number of neighbors to use.
# 'uniform': uniform weights. All points in each neighborhood are weighted equally.

# %% [markdown]
# Fitting a model means training our model on a data.
#
# **model.fit()**: fit training data.
#
# For supervised learning applications, this accepts two arguments: the data X and the labels y (e.g. model.fit(X, y)).

# %%
# Fit model (X_train, y_train)

# Enter your code here

# %% [markdown]
# **model.predict()**: given a trained model, predict the label of a new set of data.
#
# This method accepts one argument, the new data X_new (e.g. model.predict(X_new)), and returns the learned label for each object in the array.

# %%
# Predict test set

# Enter your code here

# %% [markdown]
# ## 5) Predictions and Evaluations
#
# Let's evaluate our KNN model!

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# Compute confusion matrix to evaluate the accuracy of a classification.

# %%
print(confusion_matrix(y_test, predictions))

# %% [markdown]
# Build a text report showing the main classification metrics.

# %%
print(classification_report(y_test,predictions))

# %% [markdown]
# # 6) Choosing a K Value
#
# Let's go ahead and use the elbow method to pick a good K Value:

# %%
error_rate = []

# Will take some time
for i in range(1,40):
    #print(i)

    #create model
    knn = KNeighborsClassifier(n_neighbors = i)

    # train model
    # Enter your code here ************


    # test model
    # Enter your code here ************

    #print(pred_i)
    error_rate.append(np.mean(pred_i != y_test)) #calculate error rate

# %% [markdown]
# **(pred_i != y_test)** will return a vector of boolean [True, False, ...] values.
#
# Note that != will return True for those that do not match the test values because you are interested in error.
#
# E.g.: np.mean([True, True, False]) will return 0.6666666666666666

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),
         error_rate,
         color='blue',
         linestyle='dashed',
         marker='o',
         markerfacecolor='red',
         markersize=5)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')

# %%
# Find the K value with the minimum error
best_k_index = np.argmin(error_rate)
best_k = best_k_index + 1
print(f"The best K value appears to be around: {best_k}")

# %% [markdown]
# Here we can see that that after around (K > 23) the error rate just tends to hover around 0.03-0.027
#
# Let's retrain the model with that and check the classification report!

# %%
# FIRST A QUICK COMPARISON TO OUR ORIGINAL K=1
knn = KNeighborsClassifier(n_neighbors=1)


# train model
# Enter your code here ************


# test model
# Enter your code here ***********


print('WITH K=1')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))

# %%
# NOW WITH K=23

# Enter your code here ************

# train model
# Enter your code here ************

# test model
# Enter your code here ***********

print('WITH K=23')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))

# %% [markdown]
# # Great job!
